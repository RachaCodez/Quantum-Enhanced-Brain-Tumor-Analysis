# %%
import torch
import qiskit
import qiskit_aer
import monai
import SimpleITK as sitk
import os

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")

print("-" * 20)
print(f"Qiskit-Aer version: {qiskit_aer.__version__}")
print(f"MONAI version: {monai.__version__}")

print("-" * 20)
data_path = '../data/raw/imagesTr'
if os.path.exists(data_path) and os.path.isdir(data_path) and len(os.listdir(data_path)) > 0:
    num_files = len(os.listdir(data_path))
    print(f"Found {num_files} files in {data_path}")
else:
    print(f"ERROR: Data directory not found or is empty at {data_path}. Make sure to download and extract the data correctly.")

print("\n✅ Verification complete. The Conda environment is ready!")
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA device: NVIDIA GeForce RTX 4070 Laptop GPU
# --------------------
# Qiskit-Aer version: 0.17.1
# MONAI version: 1.5.0
# --------------------
# Found 495 files in ../data/raw/imagesTr
#
# ✅ Verification complete. The Conda environment is ready!
